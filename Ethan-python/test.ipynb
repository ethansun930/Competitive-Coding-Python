# %%
(5-1) * ((7+1) / (3-1))
# Out:
# 16.0

# %%
my_list = ['item']
my_list *= 3
my_list
# Out:
# ['item', 'item', 'item']

# %%
print(my_var:="hello")
# Out:
# hello

# %%
(2 + 3j)**2
# Out:
# (-5+12j)

# %%
'Alice' 'Bob'
# Out:
# 'AliceBob'

# %%
my_name = 'Ethan'
print(f'Hi, {my_name}')
# Out:
# Hi, Ethan

# %%
a = [1, 2, 3]
if a:
    print('the list is not empty!')
# Out:
# the list is not empty!

# %%
chr(64)
# Out:
# '@'

# %%
ord('@')
# Out:
# 64

# %%
ord('o')
# Out:
# 111

# %%
q, r = divmod(29, 3)
print(q, r)
# Out:
# 9 2

# %%
my_list = [1, 2, 'a', 2, 'f', 'g']
for a, b in enumerate(my_list):
    print(a, b)
# Out:
# 0 1
# 1 2
# 2 a
# 3 2
# 4 f
# 5 g

# %%
eval('3.14')
# Out:
# 3.14

# %%
isinstance(3, int)
# Out:
# True

# %%
isinstance(5.0, int)
# Out:
# False

# %%
list((1, 2))
# Out:
# [1, 2]

# %%
isinstance(list((1, 2)), list)
# Out:
# True

# %%
list({1: 2, 2: 4, 2: 5})
# Out:
# [1, 2]

# %%
max(1, 2, 34)
# Out:
# 34

# %%
list([1])
# Out:
# [1]

# %%
set([1, 2, 3])
# Out:
# {1, 2, 3}

# %%
set((1, 2, 3))
# Out:
# {1, 2, 3}

# %%
isinstance([1], list)
# Out:
# True

# %%
a = sorted({3, 2, 1})
print(a)
# Out:
# [1, 2, 3]

# %%
str(3.14)
# Out:
# '3.14'

# %%
sum([1, 2, 3])
# Out:
# 6

# %%
a = [1, 2, 3]

# %%
a[0] = 100

# %%
a
# Out:
# [100, 2, 3]

# %%
a = (1, 2, 3)

# %%
a[0]
# Out:
# 1

# %%
a[0] = -1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 a[0] = -1
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = set([1, 2, 3])

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 a[0]
#
# TypeError: 'set' object is not subscriptable

# %%
a.add(4)

# %%
a.discard(4)

# %%
a
# Out:
# {1, 2, 3}

# %%
a.remove(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 a.remove(4)
#
# KeyError: 4

# %%
a.discard(4)

# %%
a.remove(3)

# %%
a.discard(2)

# %%
a
# Out:
# {1}

# %%
a = [1, 2, 3]

# %%
a.append(4)

# %%
b = a.pop()

# %%
b
# Out:
# 4

# %%
b = a.pop(0)

# %%
b
# Out:
# 1

# %%
a = set([1, 2, 3])

# %%
a.add(4)

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
a.add(3)

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
(False or True) and False
# Out:
# False

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
def spam():
    global eggs
    eggs = "spam"
    
eggs = "global"
spam()
print(eggs)
# Out:
# spam

# %%
a = [1, 2, 3]

# %%
b = a

# %%
b.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
c = a[:]

# %%
c.append(100)

# %%
c
# Out:
# [1, 2, 3, 4, 100]

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
list("table")
# Out:
# ['t', 'a', 'b', 'l', 'e']

# %%
"hello ethan, how are you?".split(",")
# Out:
# ['hello ethan', ' how are you?']

# %%
a, b, c = 1, 2, 3
a, b, c = b, c, a
print(a, b, c)
# Out:
# 2 3 1

# %%
a = [1, 3, 2]

# %%
a[::-1]
# Out:
# [2, 3, 1]

# %%
a = [3, 2, 1]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 3]

# %%
a = [3, 2, 1]

# %%
b = sorted(a)

# %%
a
# Out:
# [3, 2, 1]

# %%
a
# Out:
# [3, 2, 1]

# %%
b
# Out:
# [1, 2, 3]

# %%
a = "hello"

# %%
a[1]
# Out:
# 'e'

# %%
a = {1: "1", 2: "2"}

# %%
for i, b in a.items():
    print(i, b)
# Out:
# 1 1
# 2 2

# %%
int(3.14)
# Out:
# 3
